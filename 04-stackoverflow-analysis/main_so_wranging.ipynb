# %% [markdown]
# # Wrangling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df_main = pd.read_csv('developer_dataset_clean.csv', index_col='Unnamed: 0')
df_main.head()
# Out:
#    RespondentID  Year        Country          Employment UndergradMajor  \
# 1             1  2019  United States  Employed full-time        CompSci
# 2             1  2020  United States  Employed full-time        CompSci
# 3             2  2018  United States  Employed full-time        CompSci
# 4             2  2019  United States  Employed full-time        CompSci
# 5             2  2020  United States  Employed full-time        CompSci
#
#                     DevType     LanguageWorkedWith  \
# 1     Developer, full-stack                      C
# 2                       NaN               HTML/CSS
# 3     Developer, full-stack                     C#
# 4  Data or business analyst  Bash/Shell/PowerShell
# 5       Developer, back-end                 Python
#
#                               LanguageDesireNextYear  \
# 1                                C;C#;JavaScript;SQL
# 2                                    Java;Ruby;Scala
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 5                                         JavaScript
#
#                                   DatabaseWorkedWith  \
# 1                                       MySQL;SQLite
# 2                      MySQL;PostgreSQL;Redis;SQLite
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                  Couchbase;DynamoDB;Firebase;MySQL
# 5                                MariaDB;MySQL;Redis
#
#                               DatabaseDesireNextYear  \
# 1                                       MySQL;SQLite
# 2                                   MySQL;PostgreSQL
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                               Firebase;MySQL;Redis
# 5                                            MongoDB
#
#                                   PlatformWorkedWith  \
# 1                                      Linux;Windows
# 2                     AWS;Docker;Linux;MacOS;Windows
# 3                                              Azure
# 4  Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# 5                                             Docker
#
#                               PlatformDesireNextYear  YearsCodePro  \
# 1                                      Linux;Windows           1.0
# 2  Docker;Google Cloud Platform;Heroku;Linux;Windows           8.0
# 3                                              Azure           4.0
# 4  Android;AWS;Docker;IBM Cloud or Watson;Linux;S...           8.0
# 5                    iOS;Slack Apps and Integrations          13.0
#
#                                              JobSeek  ConvertedComp  \
# 1       I am not interested in new job opportunities        60000.0
# 2                                                NaN            NaN
# 3                                                NaN        50000.0
# 4       I am not interested in new job opportunities        90000.0
# 5  I’m not actively looking, but I am open to new...       120000.0
#
#    WorkWeekHrs
# 1         80.0
# 2          NaN
# 3          NaN
# 4         40.0
# 5         40.0

# %%
# # Explode
# df_main['LanguageWorkedWith'] = df_main['LanguageWorkedWith'].str.split(';')
# df_expanded = df_main.explode('LanguageWorkedWith')
# df_ohe = pd.get_dummies(df_expanded, columns=['LanguageWorkedWith'], prefix='', prefix_sep='')
# df_grouped = df_ohe.groupby(df_ohe.index).sum().reset_index(inplace=False)

# %%
df_main.columns
# Out:
# Index(['RespondentID', 'Year', 'Country', 'Employment', 'UndergradMajor',
#        'DevType', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'YearsCodePro', 'JobSeek', 'ConvertedComp',
#        'WorkWeekHrs'],
#       dtype='object')

# %%
# Disassemble into multiple frames
df_main_respondents = df_main.loc[:, ['RespondentID', 'Year', 'Country', 'Employment', 'UndergradMajor', 'DevType', 'JobSeek', 'YearsCodePro', 'ConvertedComp', 'WorkWeekHrs']]
df_resp_languages = df_main.loc[:, ['RespondentID', 'Year', 'LanguageWorkedWith', 'LanguageDesireNextYear']]
df_resp_databases = df_main.loc[:, ['RespondentID', 'Year','DatabaseWorkedWith', 'DatabaseDesireNextYear']]
df_resp_platforms = df_main.loc[:, ['RespondentID', 'Year','PlatformWorkedWith', 'PlatformDesireNextYear']]

# %%
# Dummy tables for languages
# df_resp_languages['LanguageWorkedWith'] = df_resp_languages['LanguageWorkedWith'].str.split(';').explode('LanguageWorkedWith')
# df_resp_languages_ohe = pd.get_dummies(df_resp_languages, columns=['LanguageWorkedWith'], prefix='Workedwith_', prefix_sep='')
# df_resp_languages_grouped = df_resp_languages_ohe.groupby(df_resp_languages_ohe.index).sum().reset_index(inplace=False).reset_index()

def get_dumb(df, col_name, prefix_str):
    df = df.loc[:,['RespondentID', 'Year', col_name]]
    df[col_name] = df[col_name].str.split(';').explode(col_name)
    df_ohe = pd.get_dummies(df, columns=[col_name], prefix=prefix_str, prefix_sep='')
    df_grouped = df_ohe.groupby(df_ohe.index).sum()
    return df_grouped

df_resp_languages_dummy1 = get_dumb(df_resp_languages, 'LanguageWorkedWith', 'LangWorkedWith_')
df_resp_languages_dummy2 = get_dumb(df_resp_languages, 'LanguageDesireNextYear', 'LangDesire_')
df_resp_databases1 = get_dumb(df_resp_databases, 'DatabaseWorkedWith', 'DBWorkedWith_')
df_resp_databases2 = get_dumb(df_resp_databases, 'DatabaseDesireNextYear', 'DBDesire_')
df_resp_platforms1 = get_dumb(df_resp_platforms, 'PlatformWorkedWith', 'PltfrmWorkedWith_')
df_resp_platforms2 = get_dumb(df_resp_platforms, 'PlatformDesireNextYear', 'PltfrmDesire_')

# %%
# Remerge Dummy Tables
df_resp_languages = pd.merge(df_resp_languages_dummy1, df_resp_languages_dummy2, how='inner', on=['RespondentID', 'Year'])
df_resp_databases = pd.merge(df_resp_databases1, df_resp_databases2, how='inner', on=['RespondentID', 'Year'])
df_resp_platforms = pd.merge(df_resp_platforms1, df_resp_platforms2, how='inner', on=['RespondentID', 'Year'])

# %%
df_main_respondents.head()
# Out:
#    RespondentID  Year        Country          Employment UndergradMajor  \
# 1             1  2019  United States  Employed full-time        CompSci
# 2             1  2020  United States  Employed full-time        CompSci
# 3             2  2018  United States  Employed full-time        CompSci
# 4             2  2019  United States  Employed full-time        CompSci
# 5             2  2020  United States  Employed full-time        CompSci
#
#                     DevType  \
# 1     Developer, full-stack
# 2                       NaN
# 3     Developer, full-stack
# 4  Data or business analyst
# 5       Developer, back-end
#
#                                              JobSeek  YearsCodePro  \
# 1       I am not interested in new job opportunities           1.0
# 2                                                NaN           8.0
# 3                                                NaN           4.0
# 4       I am not interested in new job opportunities           8.0
# 5  I’m not actively looking, but I am open to new...          13.0
#
#    ConvertedComp  WorkWeekHrs
# 1        60000.0         80.0
# 2            NaN          NaN
# 3        50000.0          NaN
# 4        90000.0         40.0
# 5       120000.0         40.0

# %%
df_resp_languages.groupby(['RespondentID', 'Year']).agg('sum')
# Out:
#                    LangWorkedWith_Assembly  LangWorkedWith_Bash/Shell  \
# RespondentID Year
#
#                    LangDesire_Visual Basic 6  LangDesire_WebAssembly
# RespondentID Year
# 1            2019                          0                       0
#              2020                          0                       0
# 2            2018                          0                       0
#              2019                          0                       0
#              2020                          0                       0
# ...                                      ...                     ...
# 42831        2018                          0                       0
# 42833        2018                          0                       0
# 42835        2018                          0                       0
# 42836        2018                          0                       0
# 42837        2018                          0                       0
#
# [99672 rows x 87 columns]

# %%
df_resp_databases.groupby(['RespondentID', 'Year']).agg('sum')
# Out:
#                    DBWorkedWith_Amazon DynamoDB  \
# RespondentID Year
# 1            2019                             0
#              2020                             0
# 2            2018                             0
#              2019                             0
#              2020                             0
# ...                                         ...
# 42831        2018                             0
# 42833        2018                             0
# 42835        2018                             0
# 42836        2018                             0
# 42837        2018                             0
#
#                    DBWorkedWith_Amazon RDS/Aurora  \
# RespondentID Year
# 1            2019                               0
#              2020                               0
# 2            2018                               0
#              2019                               0
#              2020                               0
# ...                                           ...
# 42831        2018                               0
# 42833        2018                               0
# 42835        2018                               0
# 42836        2018                               0
# 42837        2018                               0
#
#                    DBWorkedWith_Amazon Redshift  DBWorkedWith_Apache HBase  \
# RespondentID Year
# 1            2019                             0                          0
#              2020                             0                          0
# 2            2018                             0                          0
#              2019                             0                          0
#              2020                             0                          0
# ...                                         ...                        ...
# 42831        2018                             0                          0
# 42833        2018                             0                          0
# 42835        2018                             0                          0
# 42836        2018                             0                          0
# 42837        2018                             0                          0
#
#                    DBWorkedWith_Apache Hive  DBWorkedWith_Cassandra  \
# RespondentID Year
# 1            2019                         0                       0
#              2020                         0                       0
# 2            2018                         0                       0
#              2019                         0                       0
#              2020                         0                       0
# ...                                     ...                     ...
# 42831        2018                         0                       0
# 42833        2018                         0                       0
# 42835        2018                         0                       0
# 42836        2018                         0                       0
# 42837        2018                         0                       0
#
#                    DBWorkedWith_Couchbase  DBWorkedWith_DynamoDB  \
# RespondentID Year
# 1            2019                       0                      0
#              2020                       0                      0
# 2            2018                       0                      0
#              2019                       0                      0
#              2020                       0                      0
# ...                                   ...                    ...
# 42831        2018                       0                      0
# 42833        2018                       0                      0
# 42835        2018                       0                      0
# 42836        2018                       0                      0
# 42837        2018                       0                      0
#
#                    DBWorkedWith_Elasticsearch  DBWorkedWith_Firebase  ...  \
# RespondentID Year                                                     ...
# 1            2019                           0                      0  ...
#              2020                           0                      0  ...
# 2            2018                           0                      0  ...
#              2019                           0                      0  ...
#              2020                           0                      0  ...
# ...                                       ...                    ...  ...
# 42831        2018                           0                      0  ...
# 42833        2018                           0                      0  ...
# 42835        2018                           0                      0  ...
# 42836        2018                           0                      0  ...
# 42837        2018                           0                      0  ...
#
#                    DBDesire_Microsoft SQL Server  DBDesire_MongoDB  \
# RespondentID Year
# 1            2019                              0                 0
#              2020                              0                 0
# 2            2018                              0                 0
#              2019                              0                 0
#              2020                              0                 0
# ...                                          ...               ...
# 42831        2018                              0                 0
# 42833        2018                              0                 0
# 42835        2018                              0                 0
# 42836        2018                              0                 0
#
#                    PltfrmWorkedWith_ESP8266  PltfrmWorkedWith_Firebase  ...  \
# RespondentID Year                                                       ...
# 1            2019                         0                          0  ...
#              2020                         0                          0  ...
# 2            2018                         0                          0  ...
#              2019                         0                          0  ...
#              2020                         0                          0  ...
# ...                                     ...                        ...  ...
# 42831        2018                         0                          0  ...
# 42833        2018                         0                          0  ...
# 42835        2018                         0                          0  ...
# 42836        2018                         0                          0  ...
# 42837        2018                         0                          0  ...
#
#                    PltfrmDesire_Salesforce  PltfrmDesire_Serverless  \
# RespondentID Year
# 1            2019                        0                        0
#              2020                        0                        0
# 2            2018                        0                        0
#              2019                        0                        0
#              2020                        0                        0
# ...                                    ...                      ...
# 42831        2018                        0                        0
# 42833        2018                        0                        0
# 42835        2018                        0                        0
# 42836        2018                        0                        0
# 42837        2018                        0                        0
#
#                    PltfrmDesire_SharePoint  PltfrmDesire_Slack  \
# RespondentID Year
# 1            2019                        0                   0
#              2020                        0                   0
# 2            2018                        0                   0
#              2019                        0                   0
#              2020                        0                   0
# ...                                    ...                 ...
# 42831        2018                        0                   0
# 42833        2018                        0                   0
# 42835        2018                        0                   0
# 42836        2018                        0                   0
# 42837        2018                        0                   0
#
#                    PltfrmDesire_Slack Apps and Integrations  \
# RespondentID Year
# 1            2019                                         0
#              2020                                         0
# 2            2018                                         0
#              2019                                         0
#              2020                                         0
# ...                                                     ...
# 42831        2018                                         0
# 42833        2018                                         0
# 42835        2018                                         0
# 42836        2018                                         0
# 42837        2018                                         0
#
#                    PltfrmDesire_Windows  \
# RespondentID Year
# 1            2019                     1
#              2020                     0
# 2            2018                     0
#              2019                     0
#              2020                     0
# ...                                 ...
# 42831        2018                     0
# 42833        2018                     0
# 42835        2018                     0
# 42836        2018                     0
# 42837        2018                     0
#
#                    PltfrmDesire_Windows Desktop or Server  \
# RespondentID Year
# 1            2019                                       0
#              2020                                       0
# 2            2018                                       0
#              2019                                       0
#              2020                                       0
# ...                                                   ...
# 42831        2018                                       0
# 42833        2018                                       0
# 42835        2018                                       0
# 42836        2018                                       0
# 42837        2018                                       0
#
#                    PltfrmDesire_Windows Phone  PltfrmDesire_WordPress  \
# RespondentID Year
# 1            2019                           0                       0
#              2020                           0                       0
# 2            2018                           0                       0
#              2019                           0                       0
#              2020                           0                       0
# ...                                       ...                     ...
# 42831        2018                           0                       0
# 42833        2018                           0                       0
# 42835        2018                           0                       0
# 42836        2018                           0                       0
# 42837        2018                           0                       0
#
#                    PltfrmDesire_iOS
# RespondentID Year
# 1            2019                 0
#              2020                 0
# 2            2018                 0
#              2019                 0
#              2020                 0
# ...                             ...
# 42831        2018                 0
# 42833        2018                 0
# 42835        2018                 0
# 42836        2018                 0
# 42837        2018                 0
#
# [99672 rows x 70 columns]

# %%
# Export all
df_main_respondents.to_csv('main_respondents.csv', index=False)
df_resp_languages.to_csv('resp_languages.csv', index=False)
df_resp_databases.to_csv('resp_databases.csv', index=False)
df_resp_platforms.to_csv('resp_platforms.csv', index=False)
